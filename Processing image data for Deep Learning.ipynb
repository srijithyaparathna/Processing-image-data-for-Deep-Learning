# %%
# getting an image using web get
# !wget 'https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg'
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# Libraries tha can be used for image processing
#     1 matplotlib.image
#     2 pillow
#     3 opencv

# %%
# importing the image module from matplotlib library
import matplotlib.image as mping
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module
img = mping.imread('dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (1365, 2048, 3)

# %%
print(img)
# Out:
# [[[147 182   0]
#   [147 182   0]
#   [147 182   0]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  [[146 181   0]
#   [146 181   0]
#   [147 182   0]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  [[145 180   0]
#   [145 180   0]
#   [145 180   0]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  ...
#
#  [[ 76  69  25]
#   [ 76  69  25]
#   [ 75  68  24]
#   ...
#   [135 106  38]
#   [135 106  38]
#   [135 106  38]]
#
#  [[ 76  69  25]
#   [ 76  69  25]
#   [ 75  68  24]
#   ...
#   [135 106  38]
#   [135 106  38]
#   [135 106  38]]
#
#  [[ 76  69  25]
#   [ 76  69  25]
#   [ 75  68  24]
#   ...
#   [135 106  38]
#   [135 106  38]
#   [135 106  38]]]

# %%
print(img[:5, :5])  # prints top-left 5x5 pixels
# Out:
# [[[147 182   0]
#   [147 182   0]
#   [147 182   0]
#   [148 183   1]
#   [148 183   1]]
#
#  [[146 181   0]
#   [146 181   0]
#   [147 182   0]
#   [147 182   0]
#   [148 183   1]]
#
#  [[145 180   0]
#   [145 180   0]
#   [145 180   0]
#   [146 181   1]
#   [146 181   1]]
#
#  [[143 178   0]
#   [143 178   0]
#   [144 179   1]
#   [144 179   1]
#   [145 180   2]]
#
#  [[141 175   0]
#   [141 175   0]
#   [142 176   1]
#   [142 176   1]
#   [143 177   2]]]

# %%
# display the image form numpy array
img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing the image using PILLOW library

# %%
from PIL import Image

# %%
img = Image.open('dog.jpg')
img_resized = img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
# display the image from numpy array
img_res = mping.imread('dog_image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# Converting RGB images to grayslace image using Opencv

# %%
#  improting Opencv library
import cv2

# %%
img = cv2.imread('dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1365, 2048, 3)

# %%
grayscale_image = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (1365, 2048)

# %% [markdown]
# cv2.imshow() will display the image. But this will not be allowed in Google Colab.
#
# from google.colab.patches import cv2_imshow

# %%
import cv2
import matplotlib.pyplot as plt

# Read original image
img = cv2.imread('dog.jpg')

# Convert BGR to Grayscale
grayscale_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Save the grayscale image
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)

# Display using matplotlib
plt.imshow(grayscale_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
